# %% [markdown]
# # Qwen3 — Basic Usage (MLX)

# %% [markdown]
# ## Imports

# %%
from pprint import pprint

import mlx_lm

print("mlx-lm:", mlx_lm.__version__)
# Out:
# mlx-lm: 0.31.3

# %% [markdown]
# ## Load Model and Tokenizer

# %%
MODEL_ID = "mlx-community/Qwen3-1.7B-8bit"

model, tokenizer = mlx_lm.load(MODEL_ID)

print(f"Architecture: {model.model_type}")
print(f"Parameters: {mlx_lm.utils.get_total_parameters(model):,}")
# Out:
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Architecture: qwen3
# Parameters: 1,720,574,976

# %% [markdown]
# ## Single Turn Generation

# %%
messages = [
    {"role": "user", "content": "What is the capital of France?"},
]

chat = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True,
    enable_thinking=False,
)

print(chat)
# Out:
# <|im_start|>user
# What is the capital of France?<|im_end|>
# <|im_start|>assistant
# <think>
#
# </think>

# %%
response = mlx_lm.generate(model, tokenizer, chat, max_tokens=128)
print(response)
# Out:
# The capital of France is Paris.

# %% [markdown]
# ## System Prompt

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant who responds in all capitals."},
    {"role": "user", "content": "What is the capital of France?"},
]

chat = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True,
    enable_thinking=False,
)
print(chat)
# Out:
# <|im_start|>system
# You are a helpful assistant who responds in all capitals.<|im_end|>
# <|im_start|>user
# What is the capital of France?<|im_end|>
# <|im_start|>assistant
# <think>
#
# </think>

# %%
response = mlx_lm.generate(model, tokenizer, chat, max_tokens=128)
print(response)
# Out:
# THE CAPITAL OF FRANCE IS PARIS.

# %% [markdown]
# ## Multi-Turn Generation

# %%
messages = [
    {"role": "user", "content": "What's the capital of France?"},
]

chat = tokenizer.apply_chat_template(
    messages,
    add_generation_prompt=True,
    enable_thinking=False,
)
response = mlx_lm.generate(model, tokenizer, chat, max_tokens=128)

print(response)
# Out:
# The capital of France is Paris.

# %%
messages.append({"role": "assistant", "content": response})
pprint(messages, sort_dicts=False, width=120)
# Out:
# [{'role': 'user', 'content': "What's the capital of France?"},
#  {'role': 'assistant', 'content': 'The capital of France is Paris.'}]

# %%
prompt = "What is a famous landmark there?"

messages.append({"role": "user", "content": prompt})
pprint(messages, sort_dicts=False, width=120)
# Out:
# [{'role': 'user', 'content': "What's the capital of France?"},
#  {'role': 'assistant', 'content': 'The capital of France is Paris.'},
#  {'role': 'user', 'content': 'What is a famous landmark there?'}]

# %%
chat = tokenizer.apply_chat_template(
    messages,
    add_generation_prompt=True,
    enable_thinking=False,
)
response = mlx_lm.generate(model, tokenizer, chat, max_tokens=128)

print(response)
# Out:
# A famous landmark in Paris is the **Eiffel Tower**. It is one of the most iconic symbols of France and a popular tourist attraction. Other notable landmarks include the **Louvre Museum**, the **Sacré-Cœur Cathedral**, and the **Notre-Dame Cathedral**.

# %% [markdown]
# ## Streaming Generation

# %%
messages = [
    {"role": "user", "content": "What is the capital of France?"},
]

chat = tokenizer.apply_chat_template(
    messages,
    add_generation_prompt=True,
    enable_thinking=False,
)

for response in mlx_lm.stream_generate(model, tokenizer, chat, max_tokens=128):
    print(response.text, end="", flush=True)
# Out:
# The capital of France is Paris.
